# %%
import pandas as pd
import matplotlib.pyplot as mp

# %%
df_hillsborough = pd.read_excel('Combined.xlsx',sheet_name='Hillsborough')

# %%
df_hillsborough.columns = ['Date', 'Daily Number', 'Moving Average']

# %%
df_hillsborough.head()
# Out:
#             Date  Daily Number  Moving Average
# 0  March 1, 2020             2        2.000000
# 1  March 3, 2020             2        2.000000
# 2  March 4, 2020             1        1.666667
# 3  March 5, 2020             3        2.000000
# 4  March 6, 2020             3        2.200000

# %%
df_hillsborough.plot('Date','Daily Number', xticks=[])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_hillsborough.plot('Date','Moving Average', kind="bar", xticks=[], color="orange", width=1)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
axes=df_hillsborough.plot('Date','Daily Number', xticks=[])
df_hillsborough.plot('Date','Moving Average', xticks=[], kind="bar",color="orange",width=1, ax=axes)
# Out:
# <AxesSubplot:xlabel='Date'>
